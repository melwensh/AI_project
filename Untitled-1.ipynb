# %%
import pandas as pd # type: ignore
import numpy as np # type: ignore
import seaborn as sns # type: ignore
import matplotlib.pyplot as plt # type: ignore
from sklearn.preprocessing import LabelEncoder , MinMaxScaler # type: ignore
from sklearn.linear_model import LogisticRegression # type: ignore
from sklearn.metrics import accuracy_score , precision_score,recall_score # type: ignore
from sklearn.ensemble import RandomForestClassifier # type: ignore
from sklearn import svm # type: ignore
# %matplotlib inline

# %%
data = pd.read_csv("C:/Users/dell/Desktop/fraudTrain.csv")
data.head()
# Out:
#    ID           Time   Card Number                            merchant  \
# 0   0  1/1/2019 0:00  2.700000e+15          fraud_Rippin, Kub and Mann
# 1   1  1/1/2019 0:00  6.300000e+11     fraud_Heller, Gutmann and Zieme
# 2   2  1/1/2019 0:00  3.890000e+13                fraud_Lind-Buckridge
# 3   3  1/1/2019 0:01  3.530000e+15  fraud_Kutch, Hermiston and Farrell
# 4   4  1/1/2019 0:03  3.760000e+14                 fraud_Keeling-Crist
#
#         category  Amount  firstName lastName  \
# 0       misc_net    4.97   Jennifer    Banks
# 1    grocery_pos  107.23  Stephanie     Gill
# 2  entertainment  220.11     Edward  Sanchez
# 3  gas_transport   45.00     Jeremy    White
# 4       misc_pos   41.96      Tyler   Garcia
#
#                           trans_num  is_fraud
# 0  0b242abb623afc578575680df30655b9       0.0
# 1  1f76529f8574734946361c461b024d99       0.0
# 2  a1a22d70485983eac12b5b88dad1cf95       0.0
# 3  6b849c168bdad6f867558c3793159a81       0.0
# 4  a41d7549acf90789359a9aa5346dcb46       0.0

# %%
df = pd.read_excel("C:/Users/dell/Desktop/fraudTest.xlsx")
df.head()
# Out:
#    ID                Time       Card Number  \
# 0   0 2020-06-21 12:14:25  2291163933867240
# 1   1 2020-06-21 12:14:33  3573030041201290
# 2   2 2020-06-21 12:14:53  3598215285024750
# 3   3 2020-06-21 12:15:15  3591919803438420
# 4   4 2020-06-21 12:15:17  3526826139003040
#
#                                merchant        category  Amount firstName  \
# 0                 fraud_Kirlin and Sons   personal_care    2.86      Jeff
# 1                  fraud_Sporer-Keebler   personal_care   29.84    Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness   41.28    Ashley
# 3                     fraud_Haley Group        misc_pos   60.05     Brian
# 4                 fraud_Johnston-Casper          travel    3.19    Nathan
#
#    lastName                         trans_num  is_fraud
# 0   Elliott  2da90c7d74bd46a0caf3777415b3ebd3         0
# 1  Williams  324cc204407e99f51b0d6ca0055005e7         0
# 2     Lopez  c81755dbbbea9d5c77f094348a7579be         0
# 3  Williams  2159175b9efe66dc301f149d3d5abf8c         0
# 4    Massey  57ff021bd3f328f8738bb535c302a31b         0

# %%
len(data)
# Out:
# 1002104

# %%
len(df)
# Out:
# 555719

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1002104 entries, 0 to 1002103
# Data columns (total 10 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   ID           1002104 non-null  int64
#  1   Time         1002104 non-null  object
#  2   Card Number  1002104 non-null  float64
#  3   merchant     1002104 non-null  object
#  4   category     1002104 non-null  object
#  5   Amount       1002103 non-null  float64
#  6   firstName    1002103 non-null  object
#  7   lastName     1002103 non-null  object
#  8   trans_num    1002103 non-null  object
#  9   is_fraud     1002103 non-null  float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 76.5+ MB

# %%
df.isnull().sum()
# Out:
# ID             0
# Time           0
# Card Number    0
# merchant       0
# category       0
# Amount         0
# firstName      0
# lastName       0
# trans_num      0
# is_fraud       0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# ID             0
# Time           0
# Card Number    0
# merchant       0
# category       0
# Amount         1
# firstName      1
# lastName       1
# trans_num      1
# is_fraud       1
# dtype: int64

# %%
data=data.dropna()
data.isnull().sum()
# Out:
# ID             0
# Time           0
# Card Number    0
# merchant       0
# category       0
# Amount         0
# firstName      0
# lastName       0
# trans_num      0
# is_fraud       0
# dtype: int64

# %%
# data.boxplot('Amount')

# %%
# data.boxplot('Card Number')

# %%
# q1_Amount=data['Amount'].quantile(0.25)
# q3_Amount=data['Amount'].quantile(0.75)
# iqr_Amount=q3_Amount-q1_Amount
# upper1 = q3_Amount+(1.5*iqr_Amount)
# lower1 = q1_Amount-(1.5*iqr_Amount)
# outliers1 = data.loc[((data['Amount']>upper1) | (data['Amount']<lower1))]
# len(outliers1)

# %%
# q1_card=data['Card Number'].quantile(0.25)
# q3_card=data['Card Number'].quantile(0.75)
# iqr_card=q3_card-q1_card
# upper2 = q3_card+(1.5*iqr_card)
# lower2 = q1_card-(1.5*iqr_card)
# outliers2 = data.loc[((data['Card Number']>upper2) | (data['Card Number']<lower2))]
# len(outliers2)

# %%
# data.loc[((data['Card Number']>upper2) ,'Card Number')]=upper2
# data.loc[((data['Card Number']<lower2) , 'Card Number') ]=lower2
# data.boxplot('Card Number')

# %%
# data.loc[((data['Amount']>upper1) ,'Amount')]=upper1
# data.loc[((data['Amount']<lower1) , 'Amount') ]=lower1
# data.boxplot('Amount')

# %%
# df.boxplot('Card Number')

# %%
# df.boxplot('Amount')

# %%
# q1_Amount_df=df['Amount'].quantile(0.25)
# q3_Amount_df=df['Amount'].quantile(0.75)
# iqr_Amount_df=q3_Amount_df-q1_Amount_df
# upper1_df = q3_Amount_df+(1.5*iqr_Amount_df)
# lower1_df = q1_Amount_df-(1.5*iqr_Amount_df)
# outliers1_df = df.loc[((df['Amount']>upper1_df) | (df['Amount']<lower1_df))]
# len(outliers1_df)

# %%
# q1_card_df=df['Card Number'].quantile(0.25)
# q3_card_df=df['Card Number'].quantile(0.75)
# iqr_card_df=q3_card_df-q1_card_df
# upper2_df = q3_card_df+(1.5*iqr_card_df)
# lower2_df = q1_card_df-(1.5*iqr_card_df)
# outliers2_df = df.loc[((df['Card Number']>upper2_df) | (df['Card Number']<lower2_df))]
# len(outliers2_df)

# %%
# df.loc[((df['Card Number']>upper2_df) ,'Card Number')]=upper2_df
# df.loc[((df['Card Number']<lower2_df) , 'Card Number') ]=lower2_df
# df.boxplot('Card Number')

# %%
# df.loc[((df['Amount']>upper1_df) ,'Amount')]=upper1_df
# df.loc[((df['Amount']<lower1_df) , 'Amount') ]=lower1_df
# df.boxplot('Amount')

# %%
label_encoder = LabelEncoder()
data['category'] = label_encoder.fit_transform(data['category'])
data['firstName'] = label_encoder.fit_transform(data['firstName'])
data['lastName']= label_encoder.fit_transform(data['lastName'])
data['merchant']= label_encoder.fit_transform(data['merchant'])
data['trans_num']= label_encoder.fit_transform(data['trans_num'])
data.head()
# Out:
#    ID           Time   Card Number  merchant  category  Amount  firstName  \
# 0   0  1/1/2019 0:00  2.700000e+15       514         8    4.97        160
# 1   1  1/1/2019 0:00  6.300000e+11       241         4  107.23        305
# 2   2  1/1/2019 0:00  3.890000e+13       390         0  220.11        113
# 3   3  1/1/2019 0:01  3.530000e+15       360         2   45.00        161
# 4   4  1/1/2019 0:03  3.760000e+14       297         9   41.96        331
#
#    lastName  trans_num  is_fraud
# 0        18      43723       0.0
# 1       156     123180       0.0
# 2       379     632681       0.0
# 3       460     420764       0.0
# 4       148     642198       0.0

# %%
# data['hour_of_day'] = pd.to_datetime(data['Time']).dt.hour
# data['day_of_week'] = pd.to_datetime(data['Time']).dt.dayofweek
# data['day_of_month'] = pd.to_datetime(data['Time']).dt.day
# user_transactions = data.groupby('Card Number')['Amount']
# data['total_transaction_amount'] = user_transactions.transform('sum')
# data['avg_transaction_amount'] = user_transactions.transform('mean')
# data['amount_time_interaction'] = data['Amount'] * data['Time']
# data['amount_zscore'] = (data['Amount'] - data['Amount'].mean()) / data['Amount'].std()

data['Time'] = pd.to_datetime(data['Time'])
data['hour'] = data['Time'].dt.hour
data['day_of_week'] = data['Time'].dt.dayofweek
data['day_of_month'] = data['Time'].dt.day
data['avg_transaction_amount'] = data.groupby('is_fraud')['Amount'].transform('mean')
data['amount_diff'] = data['Amount'] - data['avg_transaction_amount']
data['transaction_count'] = data.groupby('is_fraud')['trans_num'].transform('count')
data['transactions_per_merchant'] = data.groupby(['is_fraud', 'merchant'])['trans_num'].transform('count')
data['is_suspicious_amount'] = (data['Amount'] > data['avg_transaction_amount'] * 2) | (data['Amount'] < data['avg_transaction_amount'] * 0.5)

# %%
label_encoder1 = LabelEncoder()
df['category'] = label_encoder1.fit_transform(df['category'])
df['firstName'] = label_encoder1.fit_transform(df['firstName'])
df['lastName']= label_encoder1.fit_transform(df['lastName'])
df['merchant']= label_encoder1.fit_transform(df['merchant'])
df['trans_num']= label_encoder1.fit_transform(df['trans_num'])
df.head()
# Out:
#    ID                Time       Card Number  merchant  category  Amount  \
# 0   0 2020-06-21 12:14:25  2291163933867240       319        10    2.86
# 1   1 2020-06-21 12:14:33  3573030041201290       591        10   29.84
# 2   2 2020-06-21 12:14:53  3598215285024750       611         5   41.28
# 3   3 2020-06-21 12:15:15  3591919803438420       222         9   60.05
# 4   4 2020-06-21 12:15:17  3526826139003040       292        13    3.19
#
#    firstName  lastName  trans_num  is_fraud
# 0        151       115      98699         0
# 1        163       457     108785         0
# 2         24       249     433979         0
# 3         42       457      71993         0
# 4        247       261     190585         0

# %%
# df['hour_of_day'] = pd.to_datetime(df['Time']).dt.hour
# df['day_of_week'] = pd.to_datetime(df['Time']).dt.dayofweek
# df['day_of_month'] = pd.to_datetime(df['Time']).dt.day
# user_transactions = df.groupby('Card Number')['Amount']
# df['total_transaction_amount'] = user_transactions.transform('sum')
# df['avg_transaction_amount'] = user_transactions.transform('mean')
# df['amount_time_interaction'] = df['Amount'] * df['Time']
# df['amount_zscore'] = (df['Amount'] - df['Amount'].mean()) / df['Amount'].std()

df['Time'] = pd.to_datetime(df['Time'])
df['hour'] = df['Time'].dt.hour
df['day_of_week'] = df['Time'].dt.dayofweek
df['day_of_month'] = df['Time'].dt.day
df['avg_transaction_amount'] = df.groupby('is_fraud')['Amount'].transform('mean')
df['amount_diff'] = df['Amount'] - df['avg_transaction_amount']
df['transaction_count'] = df.groupby('is_fraud')['trans_num'].transform('count')
df['transactions_per_merchant'] = df.groupby(['is_fraud', 'merchant'])['trans_num'].transform('count')
df['is_suspicious_amount'] = (df['Amount'] > df['avg_transaction_amount'] * 2) | (df['Amount'] < df['avg_transaction_amount'] * 0.5)

# %%
data['Time']= label_encoder1.fit_transform(data['Time'])
Scaler = MinMaxScaler()
x_scaler= Scaler.fit_transform(data)
data=pd.DataFrame(x_scaler, columns=data.columns)
data
# Out:
#                    ID      Time   Card Number  merchant  category    Amount  \
# 0        0.000000e+00  0.000000  5.410701e-04  0.742775  0.615385  0.000137
# 1        9.979024e-07  0.000000  1.141451e-07  0.348266  0.307692  0.003670
# 2        1.995805e-06  0.000000  7.783484e-06  0.563584  0.000000  0.007569
# 3        2.993707e-06  0.000002  7.074027e-04  0.520231  0.153846  0.001520
# 4        3.991610e-06  0.000004  7.533859e-05  0.429191  0.692308  0.001415
# ...               ...       ...           ...       ...       ...       ...
# 1002098  9.999960e-01  0.999998  6.120157e-06  0.078035  0.769231  0.003336
# 1002099  9.999970e-01  0.999998  6.039997e-06  0.891618  1.000000  0.000065
# 1002100  9.999980e-01  0.999998  6.932657e-05  0.096821  0.923077  0.000279
# 1002101  9.999990e-01  1.000000  7.623163e-06  0.591040  0.923077  0.000311
# 1002102  1.000000e+00  1.000000  6.912617e-05  0.982659  0.461538  0.000196
#
#          firstName  lastName  trans_num  is_fraud      hour  day_of_week  \
# 0         0.462428  0.037736   0.043631       0.0  0.000000     0.166667
# 1         0.881503  0.327044   0.122922       0.0  0.000000     0.166667
# 2         0.326590  0.794549   0.631354       0.0  0.000000     0.166667
# 3         0.465318  0.964361   0.419881       0.0  0.000000     0.166667
# 4         0.956647  0.310273   0.640851       0.0  0.000000     0.166667
# ...            ...       ...        ...       ...       ...          ...
# 1002098   0.719653  0.842767   0.462671       0.0  0.695652     0.833333
# 1002099   0.575145  0.226415   0.863003       0.0  0.695652     0.833333
# 1002100   0.303468  0.618449   0.977896       0.0  0.695652     0.833333
# 1002101   0.653179  0.153040   0.810390       0.0  0.695652     0.833333
# 1002102   0.132948  0.704403   0.732370       0.0  0.695652     0.833333
#
#          day_of_month  avg_transaction_amount  amount_diff  transaction_count  \
# 0            0.000000                     0.0     0.015841                1.0
# 1            0.000000                     0.0     0.019319                1.0
# 2            0.000000                     0.0     0.023157                1.0
# 3            0.000000                     0.0     0.017203                1.0
# 4            0.000000                     0.0     0.017099                1.0
# ...               ...                     ...          ...                ...
# 1002098      0.466667                     0.0     0.018990                1.0
# 1002099      0.466667                     0.0     0.015770                1.0
# 1002100      0.466667                     0.0     0.015982                1.0
# 1002101      0.466667                     0.0     0.016012                1.0
# 1002102      0.466667                     0.0     0.015899                1.0
#
#          transactions_per_merchant  is_suspicious_amount
# 0                         0.297110                   1.0
# 1                         0.572547                   0.0
# 2                         0.434979                   1.0
# 3                         0.596026                   0.0
# 4                         0.360024                   0.0
# ...                            ...                   ...
# 1002098                   0.431367                   0.0
# 1002099                   0.198675                   1.0
# 1002100                   0.533113                   1.0
# 1002101                   0.535220                   1.0
# 1002102                   0.539735                   1.0
#
# [1002103 rows x 18 columns]

# %%
df['Time']= label_encoder1.fit_transform(df['Time'])
Scaler_df = MinMaxScaler()
x_scaler_df= Scaler_df.fit_transform(df)
df=pd.DataFrame(x_scaler_df, columns=df.columns)
df
# Out:
#               ID      Time   Card Number  merchant  category    Amount  \
# 0       0.000000  0.000000  4.589232e-04  0.460983  0.769231  0.000082
# 1       0.000002  0.000002  7.156895e-04  0.854046  0.769231  0.001267
# 2       0.000004  0.000004  7.207342e-04  0.882948  0.384615  0.001769
# 3       0.000005  0.000006  7.194732e-04  0.320809  0.692308  0.002594
# 4       0.000007  0.000007  7.064345e-04  0.421965  1.000000  0.000096
# ...          ...       ...           ...       ...       ...       ...
# 555714  0.999993  0.999993  6.109391e-06  0.732659  0.384615  0.001879
# 555715  0.999995  0.999994  7.124010e-04  0.381503  0.538462  0.004868
# 555716  0.999996  0.999996  1.204176e-03  0.716763  0.538462  0.003772
# 555717  0.999998  0.999998  8.051039e-07  0.108382  1.000000  0.000307
# 555718  1.000000  1.000000  8.354046e-04  0.180636  0.000000  0.001631
#
#         firstName  lastName  trans_num  is_fraud      hour  day_of_week  \
# 0        0.444118  0.244681   0.177606       0.0  0.521739          1.0
# 1        0.479412  0.972340   0.195756       0.0  0.521739          1.0
# 2        0.070588  0.529787   0.780934       0.0  0.521739          1.0
# 3        0.123529  0.972340   0.129550       0.0  0.521739          1.0
# 4        0.726471  0.555319   0.342953       0.0  0.521739          1.0
# ...           ...       ...        ...       ...       ...          ...
# 555714   0.691176  0.670213   0.605327       0.0  1.000000          0.5
# 555715   0.502941  0.902128   0.126633       0.0  1.000000          0.5
# 555716   0.052941  0.508511   0.423035       0.0  1.000000          0.5
# 555717   0.326471  0.727660   0.078360       0.0  1.000000          0.5
# 555718   0.823529  0.308511   0.091044       0.0  1.000000          0.5
#
#         day_of_month  avg_transaction_amount  amount_diff  transaction_count  \
# 0           0.666667                     0.0     0.019883                1.0
# 1           0.666667                     0.0     0.021044                1.0
# 2           0.666667                     0.0     0.021537                1.0
# 3           0.666667                     0.0     0.022345                1.0
# 4           0.666667                     0.0     0.019897                1.0
# ...              ...                     ...          ...                ...
# 555714      1.000000                     0.0     0.021644                1.0
# 555715      1.000000                     0.0     0.024575                1.0
# 555716      1.000000                     0.0     0.023500                1.0
# 555717      1.000000                     0.0     0.020104                1.0
# 555718      1.000000                     0.0     0.021401                1.0
#
#         transactions_per_merchant  is_suspicious_amount
# 0                        0.397179                   1.0
# 1                        0.424851                   1.0
# 2                        0.408573                   0.0
# 3                        0.383614                   0.0
# 4                        0.199674                   1.0
# ...                           ...                   ...
# 555714                   0.409116                   0.0
# 555715                   0.543679                   0.0
# 555716                   0.563755                   0.0
# 555717                   0.187195                   1.0
# 555718                   0.423766                   0.0
#
# [555719 rows x 18 columns]

# %%
corr=data.corr()
corr
# Out:
#                                  ID      Time  Card Number  merchant  \
# ID                         1.000000  0.999093     0.000582  0.000572
# Time                       0.999093  1.000000     0.000553  0.000545
# Card Number                0.000582  0.000553     1.000000 -0.000482
# merchant                   0.000572  0.000545    -0.000482  1.000000
# category                   0.000707  0.000658     0.001692  0.032146
# Amount                    -0.001782 -0.001859     0.000386 -0.003202
# firstName                  0.001215  0.001192    -0.026224 -0.001336
# lastName                   0.001662  0.001665     0.007646 -0.000092
# trans_num                 -0.000372 -0.000423     0.000991 -0.000775
# is_fraud                  -0.010520 -0.011034    -0.003599 -0.000502
# hour                       0.001909  0.001631    -0.000296 -0.001230
# day_of_week                0.028155  0.030996    -0.003082 -0.000165
# day_of_month               0.046392  0.044993     0.000723 -0.001442
# avg_transaction_amount    -0.010520 -0.011034    -0.003599 -0.000502
# amount_diff                0.000515  0.000550     0.001196 -0.003168
# transaction_count          0.010520  0.011034     0.003599  0.000502
# transactions_per_merchant  0.002713  0.002896    -0.000432 -0.048437
# is_suspicious_amount       0.000372  0.000366    -0.002288  0.007470
#
#                            category    Amount  firstName  lastName  trans_num  \
# ID                         0.000707 -0.001782   0.001215  0.001662  -0.000372
# Time                       0.000658 -0.001859   0.001192  0.001665  -0.000423
# Card Number                0.001692  0.000386  -0.026224  0.007646   0.000991
# merchant                   0.032146 -0.003202  -0.001336 -0.000092  -0.000775
# category                   1.000000  0.030492  -0.001569 -0.004153  -0.000529
# Amount                     0.030492  1.000000  -0.004590 -0.004697  -0.000821
# firstName                 -0.001569 -0.004590   1.000000 -0.056099   0.000493
# lastName                  -0.004153 -0.004697  -0.056099  1.000000  -0.000339
# trans_num                 -0.000529 -0.000821   0.000493 -0.000339   1.000000
# is_fraud                   0.019908  0.217171  -0.004137  0.000358   0.001187
# hour                       0.157480 -0.022993  -0.002378  0.000447  -0.000515
# day_of_week               -0.000442 -0.001941  -0.000700  0.005186  -0.000946
# day_of_month              -0.000170  0.000602  -0.000384  0.000056   0.001144
# avg_transaction_amount     0.019908  0.217171  -0.004137  0.000358   0.001187
# amount_diff                0.026808  0.976134  -0.003781 -0.004892  -0.001105
# transaction_count         -0.019908 -0.217171   0.004137 -0.000358  -0.001187
# transactions_per_merchant -0.162575 -0.051237   0.004449 -0.000840  -0.001428
# is_suspicious_amount       0.396756 -0.039964  -0.005382  0.000433  -0.000550
#
#                                is_fraud      hour  day_of_week  day_of_month  \
# ID                        -1.052043e-02  0.001909     0.028155      0.046392
# Time                      -1.103414e-02  0.001631     0.030996      0.044993
# Card Number               -3.599213e-03 -0.000296    -0.003082      0.000723
# merchant                  -5.021849e-04 -0.001230    -0.000165     -0.001442
# category                   1.990816e-02  0.157480    -0.000442     -0.000170
# Amount                     2.171710e-01 -0.022993    -0.001941      0.000602
# firstName                 -4.137105e-03 -0.002378    -0.000700     -0.000384
# lastName                   3.580414e-04  0.000447     0.005186      0.000056
# trans_num                  1.187365e-03 -0.000515    -0.000946      0.001144
# is_fraud                   1.000000e+00  0.012535     0.000755      0.004864
# hour                       1.253489e-02  1.000000     0.002074      0.000562
# day_of_week                7.554489e-04  0.002074     1.000000      0.008037
# day_of_month               4.864427e-03  0.000562     0.008037      1.000000
# avg_transaction_amount     1.000000e+00  0.012535     0.000755      0.004864
# amount_diff                2.517864e-15 -0.026344    -0.002156     -0.000466
# transaction_count         -1.000000e+00 -0.012535    -0.000755     -0.004864
# transactions_per_merchant -2.781206e-01 -0.085028    -0.001371     -0.001036
# is_suspicious_amount      -2.681996e-02  0.168567     0.001178      0.000300
#
#                            avg_transaction_amount   amount_diff  \
# ID                                  -1.052043e-02  5.149573e-04
# Time                                -1.103414e-02  5.500000e-04
# Card Number                         -3.599213e-03  1.196374e-03
# merchant                            -5.021849e-04 -3.168208e-03
# category                             1.990816e-02  2.680802e-02
# Amount                               2.171710e-01  9.761336e-01
# firstName                           -4.137105e-03 -3.781295e-03
# lastName                             3.580414e-04 -4.891538e-03
# trans_num                            1.187365e-03 -1.105113e-03
# is_fraud                             1.000000e+00  2.517864e-15
# hour                                 1.253489e-02 -2.634353e-02
# day_of_week                          7.554489e-04 -2.156062e-03
# day_of_month                         4.864427e-03 -4.657349e-04
# avg_transaction_amount               1.000000e+00  2.517864e-15
# amount_diff                          2.517864e-15  1.000000e+00
# transaction_count                   -1.000000e+00 -2.547324e-15
# transactions_per_merchant           -2.781206e-01  9.386787e-03
# is_suspicious_amount                -2.681996e-02 -3.497452e-02
#
#                            transaction_count  transactions_per_merchant  \
# ID                              1.052043e-02                   0.002713
# Time                            1.103414e-02                   0.002896
# Card Number                     3.599213e-03                  -0.000432
# merchant                        5.021849e-04                  -0.048437
# category                       -1.990816e-02                  -0.162575
# Amount                         -2.171710e-01                  -0.051237
# firstName                       4.137105e-03                   0.004449
# lastName                       -3.580414e-04                  -0.000840
# trans_num                      -1.187365e-03                  -0.001428
# is_fraud                       -1.000000e+00                  -0.278121
# hour                           -1.253489e-02                  -0.085028
# day_of_week                    -7.554489e-04                  -0.001371
# day_of_month                   -4.864427e-03                  -0.001036
# avg_transaction_amount         -1.000000e+00                  -0.278121
# amount_diff                    -2.547324e-15                   0.009387
# transaction_count               1.000000e+00                   0.278121
# transactions_per_merchant       2.781206e-01                   1.000000
# is_suspicious_amount            2.681996e-02                  -0.190146
#
#                            is_suspicious_amount
# ID                                     0.000372
# Time                                   0.000366
# Card Number                           -0.002288
# merchant                               0.007470
# category                               0.396756
# Amount                                -0.039964
# firstName                             -0.005382
# lastName                               0.000433
# trans_num                             -0.000550
# is_fraud                              -0.026820
# hour                                   0.168567
# day_of_week                            0.001178
# day_of_month                           0.000300
# avg_transaction_amount                -0.026820
# amount_diff                           -0.034975
# transaction_count                      0.026820
# transactions_per_merchant             -0.190146
# is_suspicious_amount                   1.000000

# %%
data.drop(['ID', 'Time', 'firstName', 'lastName', 'trans_num','Amount','category','merchant','Card Number'], axis=1,inplace=True)
data
# Out:
#          is_fraud      hour  day_of_week  day_of_month  \
# 0             0.0  0.000000     0.166667      0.000000
# 1             0.0  0.000000     0.166667      0.000000
# 2             0.0  0.000000     0.166667      0.000000
# 3             0.0  0.000000     0.166667      0.000000
# 4             0.0  0.000000     0.166667      0.000000
# ...           ...       ...          ...           ...
# 1002098       0.0  0.695652     0.833333      0.466667
# 1002099       0.0  0.695652     0.833333      0.466667
# 1002100       0.0  0.695652     0.833333      0.466667
# 1002101       0.0  0.695652     0.833333      0.466667
# 1002102       0.0  0.695652     0.833333      0.466667
#
#          avg_transaction_amount  amount_diff  transaction_count  \
# 0                           0.0     0.015841                1.0
# 1                           0.0     0.019319                1.0
# 2                           0.0     0.023157                1.0
# 3                           0.0     0.017203                1.0
# 4                           0.0     0.017099                1.0
# ...                         ...          ...                ...
# 1002098                     0.0     0.018990                1.0
# 1002099                     0.0     0.015770                1.0
# 1002100                     0.0     0.015982                1.0
# 1002101                     0.0     0.016012                1.0
# 1002102                     0.0     0.015899                1.0
#
#          transactions_per_merchant  is_suspicious_amount
# 0                         0.297110                   1.0
# 1                         0.572547                   0.0
# 2                         0.434979                   1.0
# 3                         0.596026                   0.0
# 4                         0.360024                   0.0
# ...                            ...                   ...
# 1002098                   0.431367                   0.0
# 1002099                   0.198675                   1.0
# 1002100                   0.533113                   1.0
# 1002101                   0.535220                   1.0
# 1002102                   0.539735                   1.0
#
# [1002103 rows x 9 columns]

# %%
corr_df=df.corr()
corr_df
# Out:
#                                  ID      Time  Card Number  merchant  \
# ID                         1.000000  0.999998    -0.000823 -0.000832
# Time                       0.999998  1.000000    -0.000822 -0.000839
# Card Number               -0.000823 -0.000822     1.000000  0.001326
# merchant                  -0.000832 -0.000839     0.001326  1.000000
# category                   0.001480  0.001470    -0.001779  0.028033
# Amount                    -0.001137 -0.001132     0.001963 -0.003780
# firstName                  0.000940  0.000937    -0.030216 -0.001027
# lastName                   0.001603  0.001605     0.007260 -0.000512
# trans_num                  0.001368  0.001367    -0.000125 -0.000028
# is_fraud                  -0.013892 -0.013864    -0.001540 -0.000086
# hour                       0.000667  0.000643    -0.001137 -0.000171
# day_of_week               -0.013665 -0.013572     0.003031 -0.000864
# day_of_month               0.064132  0.063582    -0.001735  0.000933
# avg_transaction_amount    -0.013892 -0.013864    -0.001540 -0.000086
# amount_diff                0.001419  0.001419     0.002282 -0.003828
# transaction_count          0.013892  0.013864     0.001540  0.000086
# transactions_per_merchant  0.003987  0.003983    -0.001148 -0.048605
# is_suspicious_amount       0.002191  0.002184    -0.002914  0.005676
#
#                            category    Amount  firstName  lastName  trans_num  \
# ID                         0.001480 -0.001137   0.000940  0.001603   0.001368
# Time                       0.001470 -0.001132   0.000937  0.001605   0.001367
# Card Number               -0.001779  0.001963  -0.030216  0.007260  -0.000125
# merchant                   0.028033 -0.003780  -0.001027 -0.000512  -0.000028
# category                   1.000000  0.026811  -0.002089 -0.002702  -0.001348
# Amount                     0.026811  1.000000   0.000584 -0.006236  -0.002609
# firstName                 -0.002089  0.000584   1.000000 -0.058780  -0.002572
# lastName                  -0.002702 -0.006236  -0.058780  1.000000  -0.002153
# trans_num                 -0.001348 -0.002609  -0.002572 -0.002153   1.000000
# is_fraud                   0.016980  0.182267  -0.001725 -0.001203  -0.002816
# hour                       0.157214 -0.029860  -0.005414  0.000316  -0.000413
# day_of_week               -0.001757  0.003414   0.000344 -0.004573   0.001748
# day_of_month               0.000558 -0.000829   0.000110  0.002502  -0.001550
# avg_transaction_amount     0.016980  0.182267  -0.001725 -0.001203  -0.002816
# amount_diff                0.024120  0.983249   0.000914 -0.006119  -0.002131
# transaction_count         -0.016980 -0.182267   0.001725  0.001203   0.002816
# transactions_per_merchant -0.155360 -0.033850   0.002188  0.001390   0.003540
# is_suspicious_amount       0.394933 -0.037327  -0.005424  0.001860  -0.001510
#
#                                is_fraud      hour  day_of_week  day_of_month  \
# ID                        -1.389208e-02  0.000667    -0.013665      0.064132
# Time                      -1.386372e-02  0.000643    -0.013572      0.063582
# Card Number               -1.540299e-03 -0.001137     0.003031     -0.001735
# merchant                  -8.641702e-05 -0.000171    -0.000864      0.000933
# category                   1.698030e-02  0.157214    -0.001757      0.000558
# Amount                     1.822671e-01 -0.029860     0.003414     -0.000829
# firstName                 -1.724576e-03 -0.005414     0.000344      0.000110
# lastName                  -1.202765e-03  0.000316    -0.004573      0.002502
# trans_num                 -2.816135e-03 -0.000413     0.001748     -0.001550
# is_fraud                   1.000000e+00  0.011686     0.009365     -0.009203
# hour                       1.168556e-02  1.000000     0.001516     -0.000161
# day_of_week                9.364763e-03  0.001516     1.000000     -0.038866
# day_of_month              -9.203388e-03 -0.000161    -0.038866      1.000000
# avg_transaction_amount     1.000000e+00  0.011686     0.009365     -0.009203
# amount_diff                3.241186e-16 -0.032535     0.001736      0.000863
# transaction_count         -1.000000e+00 -0.011686    -0.009365      0.009203
# transactions_per_merchant -2.322270e-01 -0.087231     0.000228      0.000730
# is_suspicious_amount      -2.044501e-02  0.168249    -0.000282      0.002596
#
#                            avg_transaction_amount   amount_diff  \
# ID                                  -1.389208e-02  1.418974e-03
# Time                                -1.386372e-02  1.418987e-03
# Card Number                         -1.540299e-03  2.281729e-03
# merchant                            -8.641702e-05 -3.828078e-03
# category                             1.698030e-02  2.411959e-02
# Amount                               1.822671e-01  9.832491e-01
# firstName                           -1.724576e-03  9.137464e-04
# lastName                            -1.202765e-03 -6.119234e-03
# trans_num                           -2.816135e-03 -2.130942e-03
# is_fraud                             1.000000e+00  3.241186e-16
# hour                                 1.168556e-02 -3.253535e-02
# day_of_week                          9.364763e-03  1.735982e-03
# day_of_month                        -9.203388e-03  8.625192e-04
# avg_transaction_amount               1.000000e+00  3.241186e-16
# amount_diff                          3.241186e-16  1.000000e+00
# transaction_count                   -1.000000e+00 -5.849201e-16
# transactions_per_merchant           -2.322270e-01  8.621683e-03
# is_suspicious_amount                -2.044501e-02 -3.417255e-02
#
#                            transaction_count  transactions_per_merchant  \
# ID                              1.389208e-02                   0.003987
# Time                            1.386372e-02                   0.003983
# Card Number                     1.540299e-03                  -0.001148
# merchant                        8.641702e-05                  -0.048605
# category                       -1.698030e-02                  -0.155360
# Amount                         -1.822671e-01                  -0.033850
# firstName                       1.724576e-03                   0.002188
# lastName                        1.202765e-03                   0.001390
# trans_num                       2.816135e-03                   0.003540
# is_fraud                       -1.000000e+00                  -0.232227
# hour                           -1.168556e-02                  -0.087231
# day_of_week                    -9.364763e-03                   0.000228
# day_of_month                    9.203388e-03                   0.000730
# avg_transaction_amount         -1.000000e+00                  -0.232227
# amount_diff                    -5.849201e-16                   0.008622
# transaction_count               1.000000e+00                   0.232227
# transactions_per_merchant       2.322270e-01                   1.000000
# is_suspicious_amount            2.044501e-02                  -0.191895
#
#                            is_suspicious_amount
# ID                                     0.002191
# Time                                   0.002184
# Card Number                           -0.002914
# merchant                               0.005676
# category                               0.394933
# Amount                                -0.037327
# firstName                             -0.005424
# lastName                               0.001860
# trans_num                             -0.001510
# is_fraud                              -0.020445
# hour                                   0.168249
# day_of_week                           -0.000282
# day_of_month                           0.002596
# avg_transaction_amount                -0.020445
# amount_diff                           -0.034173
# transaction_count                      0.020445
# transactions_per_merchant             -0.191895
# is_suspicious_amount                   1.000000

# %%
df.drop(['ID', 'Time', 'firstName', 'lastName', 'trans_num','Amount','category','merchant','Card Number'], axis=1,inplace=True)
df
# Out:
#         is_fraud      hour  day_of_week  day_of_month  avg_transaction_amount  \
# 0            0.0  0.521739          1.0      0.666667                     0.0
# 1            0.0  0.521739          1.0      0.666667                     0.0
# 2            0.0  0.521739          1.0      0.666667                     0.0
# 3            0.0  0.521739          1.0      0.666667                     0.0
# 4            0.0  0.521739          1.0      0.666667                     0.0
# ...          ...       ...          ...           ...                     ...
# 555714       0.0  1.000000          0.5      1.000000                     0.0
# 555715       0.0  1.000000          0.5      1.000000                     0.0
# 555716       0.0  1.000000          0.5      1.000000                     0.0
# 555717       0.0  1.000000          0.5      1.000000                     0.0
# 555718       0.0  1.000000          0.5      1.000000                     0.0
#
#         amount_diff  transaction_count  transactions_per_merchant  \
# 0          0.019883                1.0                   0.397179
# 1          0.021044                1.0                   0.424851
# 2          0.021537                1.0                   0.408573
# 3          0.022345                1.0                   0.383614
# 4          0.019897                1.0                   0.199674
# ...             ...                ...                        ...
# 555714     0.021644                1.0                   0.409116
# 555715     0.024575                1.0                   0.543679
# 555716     0.023500                1.0                   0.563755
# 555717     0.020104                1.0                   0.187195
# 555718     0.021401                1.0                   0.423766
#
#         is_suspicious_amount
# 0                        1.0
# 1                        1.0
# 2                        0.0
# 3                        0.0
# 4                        1.0
# ...                      ...
# 555714                   0.0
# 555715                   0.0
# 555716                   0.0
# 555717                   1.0
# 555718                   0.0
#
# [555719 rows x 9 columns]

# %%
x_train = data.drop(columns=['is_fraud']) 
y_train = data['is_fraud']
x_test = df.drop(columns=['is_fraud']) 
y_test = df['is_fraud']
model = LogisticRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
count = np.sum(y_pred== 1)
accuracy = accuracy_score(y_test, y_pred)
recall = recall_score(y_test, y_pred,average='binary')
precision=precision_score(y_test, y_pred,zero_division=1)
F1_score =(2*recall*precision)/(recall+precision)
print("Accuracy:", accuracy)
print("Recall:", recall)
print("Precision:", precision)
print("F1-score:", F1_score)
print(count)
# model=svm.SVC(kernel='linear')
# model  = RandomForestClassifier(n_estimators=100, random_state=42)
# report = classification_report(y_test, y_pred,zero_division=1)
# print("Classification Report:\n", report)
# y_pred2=model.predict(x_train)
# accuracy2 = accuracy_score(y_train, y_pred2)
# print("Accuracy:", accuracy2)
# model.score(x_test,y_test)
# model.score(x_train,y_train)
# Out:
# Accuracy: 1.0
# Recall: 1.0
# Precision: 1.0
# F1-score: 1.0
# 2145

# %%
y_pred_train = model.predict(x_train)
count = np.sum(y_pred_train== 1)
accuracy = accuracy_score(y_train, y_pred_train)
recall = recall_score(y_train, y_pred_train,average='binary')
precision=precision_score(y_train, y_pred_train,zero_division=1)
F1_score =(2*recall*precision)/(recall+precision)
print("Accuracy:", accuracy)
print("Recall:", recall)
print("Precision:", precision)
print("F1-score:", F1_score)
print(count)
# Out:
# Accuracy: 1.0
# Recall: 1.0
# Precision: 1.0
# F1-score: 1.0
# 5713
